# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import csv
#Folder path must end with /
FOLDER = "/Users/echo/Documents/0424_Data_Enrichment/Project-3/Data/"

# %%
#Reading in 2000 movies from above output
results00 = pd.read_csv("/Users/echo/Documents/0424_Data_Enrichment/Project-3/Data/final_tmdb_data_2000.csv.gz")
results00
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1244  tt6174238    0.0                               NaN
# 1245  tt7029820    0.0                               NaN
# 1246  tt7197642    0.0                               NaN
# 1247  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 1248  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...                    ...         ...
# 1244                   NaN         0.0
# 1245                   NaN      7000.0
# 1246                   NaN         0.0
# 1247                   NaN  10000000.0
# 1248                   NaN         0.0
#
#                                                  genres homepage        id  \
# 0                                                   NaN      NaN       NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 2              [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977.0
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  442869.0
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN     843.0
# ...                                                 ...      ...       ...
# 1244                      [{'id': 80, 'name': 'Crime'}]      NaN  223878.0
# 1245                                                 []      NaN  604889.0
# 1246                     [{'id': 35, 'name': 'Comedy'}]      NaN  872676.0
# 1247                     [{'id': 27, 'name': 'Horror'}]      NaN   97186.0
# 1248  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN  610992.0
#
#      original_language           original_title  ...     revenue  runtime  \
# 0                  NaN                      NaN  ...         NaN      NaN
# 1                   en          The Fantasticks  ...         0.0     86.0
# 2                   en            For the Cause  ...         0.0    100.0
# 3                   hi                     Gang  ...         0.0    152.0
# 4                   cn                     花樣年華  ...  14204632.0     99.0
# ...                ...                      ...  ...         ...      ...
# 1244                cn                       冷战  ...         0.0      0.0
# 1245                en     Scream For Christmas  ...         0.0     80.0
# 1246                en  Goodbye, Merry-Go-Round  ...         0.0     90.0
# 1247                fr               I, Vampire  ...         0.0     85.0
# 1248                fa                مومیایی ۳  ...         0.0     98.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# ...                                                 ...       ...
# 1244  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1245                                                 []  Released
# 1246                                                 []  Released
# 1247  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1248  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1         Try to remember the first time magic happened
# 2          The ultimate showdown on a forbidden planet.
# 3                                                   NaN
# 4     Feel the heat, keep the feeling burning, let t...
# ...                                                 ...
# 1244                                                NaN
# 1245                                                NaN
# 1246                                                NaN
# 1247                                                NaN
# 1248                                                NaN
#
#                         title  video  vote_average vote_count certification
# 0                         NaN    NaN           NaN        NaN           NaN
# 1             The Fantasticks    0.0          5.50       22.0           NaN
# 2               For the Cause    0.0          5.45       10.0           NaN
# 3                        Gang    0.0          4.00        1.0           NaN
# 4        In the Mood for Love    0.0          8.11     2268.0            PG
# ...                       ...    ...           ...        ...           ...
# 1244                 Cold War    0.0          2.00        2.0           NaN
# 1245     Scream For Christmas    0.0          0.00        0.0           NaN
# 1246  Goodbye, Merry-Go-Round    0.0          0.00        0.0           NaN
# 1247               I, Vampire    0.0          6.40        4.0            NR
# 1248              The Mummy 3    0.0          7.00        1.0           NaN
#
# [1249 rows x 26 columns]

# %%
#Reading in 2001 movies from above output
results01 = pd.read_csv("/Users/echo/Documents/0424_Data_Enrichment/Project-3/Data/final_tmdb_data_2001.csv.gz")
results01
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# ...         ...    ...                               ...
# 1339  tt7797790    0.0                               NaN
# 1340  tt8665056    0.0                               NaN
# 1341  tt8795764    0.0                               NaN
# 1342  tt9071078    0.0                               NaN
# 1343  tt9212730    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  22000000.0
# ...                    ...         ...
# 1339                   NaN         0.0
# 1340                   NaN         0.0
# 1341                   NaN         0.0
# 1342                   NaN         0.0
# 1343                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...
# 2     [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 3     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# ...                                                 ...
# 1339                     [{'id': 27, 'name': 'Horror'}]
# 1340                    [{'id': 37, 'name': 'Western'}]
# 1341                     [{'id': 27, 'name': 'Horror'}]
# 1342                     [{'id': 28, 'name': 'Action'}]
# 1343  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   11232.0
# 2                                                   NaN  151007.0
# 3                                                   NaN   73549.0
# 4                                                   NaN   10696.0
# ...                                                 ...       ...
# 1339                                                NaN  956219.0
# 1340  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 1341  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 1342                                                NaN  201706.0
# 1343                                                NaN  382630.0
#
#      original_language                       original_title  ...     revenue  \
# 0                  NaN                                  NaN  ...         NaN
# 1                   en                       Kate & Leopold  ...  76019048.0
# 2                   en                     The Silent Force  ...         0.0
# 3                   en                        The Dark Mist  ...         0.0
# 4                   en                              Glitter  ...   5271666.0
# ...                ...                                  ...  ...         ...
# 1339                en  Edmund Kemper Part 3: La mort sévit  ...         0.0
# 1340                en                 Guns Along The Bravo  ...         0.0
# 1341                en                            New Breed  ...         0.0
# 1342                cn                                 致命密函  ...         0.0
# 1343                ja                           実録外伝 ゾンビ極道  ...         0.0
#
#       runtime                                   spoken_languages    status  \
# 0         NaN                                                NaN       NaN
# 1       118.0  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2        90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3       101.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4       104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...       ...                                                ...       ...
# 1339     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 1340     85.0                                                 []  Released
# 1341     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1342     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1343     88.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1     If they lived in the same century, they'd be p...
# 2     They left him for dead... They should have fin...
# 3                                                   NaN
# 4      In music she found her dream, her love, herself.
# ...                                                 ...
# 1339                                                NaN
# 1340  Evil came to the Southwest until three blazing...
# 1341                                                NaN
# 1342                                                NaN
# 1343                                                NaN
#
#                                     title  video  vote_average vote_count  \
# 0                                     NaN    NaN           NaN        NaN
# 1                          Kate & Leopold    0.0         6.331     1212.0
# 2                        The Silent Force    0.0         5.000        3.0
# 3                           The Dark Mist    0.0         3.500        2.0
# 4                                 Glitter    0.0         4.449      128.0
# ...                                   ...    ...           ...        ...
# 1339  Edmund Kemper Part 3: La mort sévit    0.0         0.000        0.0
# 1340                 Guns Along The Bravo    0.0         0.000        0.0
# 1341                            New Breed    0.0         0.000        0.0
# 1342                       Chinese Heroes    0.0         3.000        2.0
# 1343                        Yakuza Zombie    0.0         0.000        0.0
#
#      certification
# 0              NaN
# 1            PG-13
# 2              NaN
# 3               PG
# 4            PG-13
# ...            ...
# 1339           NaN
# 1340           NaN
# 1341            NR
# 1342           NaN
# 1343           NaN
#
# [1344 rows x 26 columns]

# %%
#Concatenate the data into 1 dataframe for the remainder of the analysis.
df = pd.concat([results00, results01], ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2593 entries, 0 to 2592
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2593 non-null   object
#  1   adult                  2591 non-null   float64
#  2   backdrop_path          1429 non-null   object
#  3   belongs_to_collection  211 non-null    object
#  4   budget                 2591 non-null   float64
#  5   genres                 2591 non-null   object
#  6   homepage               171 non-null    object
#  7   id                     2591 non-null   float64
#  8   original_language      2591 non-null   object
#  9   original_title         2591 non-null   object
#  10  overview               2547 non-null   object
#  11  popularity             2591 non-null   float64
#  12  poster_path            2347 non-null   object
#  13  production_companies   2591 non-null   object
#  14  production_countries   2591 non-null   object
#  15  release_date           2570 non-null   object
#  16  revenue                2591 non-null   float64
#  17  runtime                2591 non-null   float64
#  18  spoken_languages       2591 non-null   object
#  19  status                 2591 non-null   object
#  20  tagline                1115 non-null   object
#  21  title                  2591 non-null   object
#  22  video                  2591 non-null   float64
#  23  vote_average           2591 non-null   float64
#  24  vote_count             2591 non-null   float64
#  25  certification          812 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 526.8+ KB

# %% [markdown]
# 1. How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
# Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.

# %%
#Filter for movies that made money.
valid_movies = df[(df["budget"] > 0) | (df["revenue"] > 0)]
valid_movies = valid_movies.shape[0]
valid_movies
# Out:
# 642

# %% [markdown]
# 2. How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
#Finding count for each certification category
df["certification"].value_counts()
# Out:
# R          466
# PG-13      182
# NR          71
# PG          62
# G           24
# NC-17        6
# Unrated      1
# Name: certification, dtype: int64

# %% [markdown]
# 3. What is the average revenue per certification category? (per million)

# %%
#Grouping ratings together and finding average revenue
avg_revenue_per_rating = df.groupby("certification")["revenue"].mean()
avg_revenue_per_rating
# Out:
# certification
# G          7.335298e+07
# NC-17      0.000000e+00
# NR         2.295880e+06
# PG         6.248013e+07
# PG-13      7.146544e+07
# R          1.529026e+07
# Unrated    0.000000e+00
# Name: revenue, dtype: float64

# %% [markdown]
# 4. What is the average budget per certification category? (per million)

# %%
#Getting the budget of each rating
avg_budget_per_rating = df.groupby("certification")["budget"].mean()
avg_budget_per_rating
# Out:
# certification
# G          2.383333e+07
# NC-17      0.000000e+00
# NR         1.509015e+06
# PG         2.530641e+07
# PG-13      3.094592e+07
# R          9.501726e+06
# Unrated    0.000000e+00
# Name: budget, dtype: float64

# %%
#Saving combined dataset into one file
df.to_csv(f"{FOLDER}tmdb_results_combined.csv.gz", compression="gzip", index=False)
